# %%
# %env PYSYS_PRIVATE_CONFIG_DIR=/home/alpha/pst_private/prod
import pandas as pd
import matplotlib.pyplot as plt
from sysobjects.dict_of_futures_per_contract_prices import dictFuturesContractPrices
from sysobjects.futures_per_contract_prices import futuresContractPrices
from sysproduction.data.prices import diagPrices

# prices from parquet
diag_prices = diagPrices()
prices = diag_prices.db_futures_contract_price_data
INSTR = 'BUND'

# contract prices
price_dict = prices.get_merged_prices_for_instrument(INSTR)
contract_data = dict([(contractid, data) for contractid, data in price_dict.items()])
all_contract_data = dictFuturesContractPrices([(key, futuresContractPrices(x)) for key, x in contract_data.items()])
contract_prices_final = all_contract_data.final_prices()
all_finals = pd.concat(contract_prices_final, axis=1)
all_finals.plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Individual Parquet contract prices for {INSTR}")

# multiple prices
db_multiple_prices = diag_prices.db_futures_multiple_prices_data
db_multiple_prices.get_multiple_prices(INSTR).plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Multiple prices for {INSTR}")
plt.show()

# adjusted prices
db_adjusted_prices = diag_prices.db_futures_adjusted_prices_data
print("Adjusted prices for",(INSTR))
print(db_adjusted_prices.get_adjusted_prices(INSTR))
db_adjusted_prices.get_adjusted_prices(INSTR).plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR}")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2025-01-01":"2025-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2025")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2024-01-01":"2024-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2024")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2023-01-01":"2023-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2023")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2022-01-01":"2022-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2022")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2021-01-01":"2021-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2021")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2020-01-01":"2020-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2020")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2019-01-01":"2019-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2019")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2018-01-01":"2018-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2018")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2017-01-01":"2017-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2017")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2016-01-01":"2016-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2016")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2015-01-01":"2015-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2015")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2014-01-01":"2014-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2014")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2013-01-01":"2013-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2013")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2012-01-01":"2012-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2012")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2011-01-01":"2011-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2011")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2010-01-01":"2010-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2010")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2009-01-01":"2009-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2009")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2008-01-01":"2008-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2008")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2007-01-01":"2007-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2007")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2006-01-01":"2006-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2006")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2005-01-01":"2005-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2005")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2004-01-01":"2004-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2004")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2003-01-01":"2003-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2003")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2002-01-01":"2002-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2002")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2001-01-01":"2001-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2001")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["2000-01-01":"2000-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 2000")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1999-01-01":"1999-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1999")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1998-01-01":"1998-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1998")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1997-01-01":"1997-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1997")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1996-01-01":"1996-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1996")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1995-01-01":"1995-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1995")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1994-01-01":"1994-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1994")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1993-01-01":"1993-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1993")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1992-01-01":"1992-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1992")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1991-01-01":"1991-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1991")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1990-01-01":"1990-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1990")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1989-01-01":"1989-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1989")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1988-01-01":"1988-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1988")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1987-01-01":"1987-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1987")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1986-01-01":"1986-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1986")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1985-01-01":"1985-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1985")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1984-01-01":"1984-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1984")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1983-01-01":"1983-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1983")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1982-01-01":"1982-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1982")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1981-01-01":"1981-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1981")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1980-01-01":"1980-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1980")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1979-01-01":"1979-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1979")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1978-01-01":"1978-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1978")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1977-01-01":"1977-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1977")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1976-01-01":"1976-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1976")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1975-01-01":"1975-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1975")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1974-01-01":"1974-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1974")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1973-01-01":"1973-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1973")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1972-01-01":"1972-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1972")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1971-01-01":"1971-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1971")
plt.show(); db_adjusted_prices.get_adjusted_prices(INSTR)["1970-01-01":"1970-12-31"].plot(figsize=(15,9), legend=False, lw=1, grid=True, title=f"Adjusted prices for {INSTR} year 1970")
